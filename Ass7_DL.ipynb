# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warningsP
import datetime
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import r2_score
# Out:
# 2026-03-25 13:09:22.889719: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-25 13:09:22.894734: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-25 13:09:22.924799: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774424362.965996   27901 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774424362.972873   27901 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774424363.006658   27901 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774424363.006742   27901 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774424363.006745   27901 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774424363.006747   27901 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-25 13:09:23.011877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#data=pd.read_csv("/content/Google_Stock_Price_Train.csv",index_col='Date',parse_dates=True)
data=pd.read_csv("/home/student/Google_Stock_Price_Train.csv")
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
data['Close']=data['Close'].str.replace(',','').astype(float)
data['Volume']=data['Volume'].str.replace(',','').astype(float)

# %%
ax1 = data.plot(x="Date", y=["Open", "High", "Low", "Close"],  figsize=(18,10),title='Open, High, Low, Close Stock Prices of Google Stocks')
ax1.set_ylabel("Stock Price")

ax2 = data.plot(x="Date", y=["Volume"],  figsize=(18,9))
ax2.set_ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %%
# Getting a summary of missing values for each field/attribute
print(data.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
data[['Open','High','Low','Close','Volume']].plot(kind= 'box' ,layout=(1,5),subplots=True, sharex=False, sharey=False, figsize=(20,6),color='blue')
plt.show()

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Volume'}>, <Axes: >]], dtype=object)

# %%
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7380500.0
# 1       1/4/2012  331.27  333.87  329.08  666.45   5749400.0
# 2       1/5/2012  329.83  330.75  326.89  657.21   6590300.0
# 3       1/6/2012  328.34  328.77  323.68  648.24   5405900.0
# 4       1/9/2012  322.04  322.29  309.46  620.76  11688800.0
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91    623400.0
# 1254  12/27/2016  790.68  797.86  787.66  791.55    789100.0
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1153800.0
# 1256  12/29/2016  783.33  785.93  778.92  782.79    744300.0
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1770000.0
#
# [1258 rows x 6 columns]

# %%
scaler = MinMaxScaler()
data_without_date = data[['Open','High','Low','Close','Volume']]
data_scaled = pd.DataFrame(scaler.fit_transform(data_without_date))

# %%
data_scaled
# Out:
#              0         1         2         3         4
# 0     0.085814  0.096401  0.090449  0.237573  0.295258
# 1     0.097012  0.098344  0.098235  0.241514  0.229936
# 2     0.094334  0.092517  0.094086  0.228781  0.263612
# 3     0.091562  0.088819  0.088006  0.216419  0.216179
# 4     0.079842  0.076718  0.061070  0.178548  0.467797
# ...        ...       ...       ...       ...       ...
# 1253  0.952043  0.955292  0.966169  0.411656  0.024650
# 1254  0.951633  0.964853  0.966889  0.413916  0.031286
# 1255  0.957251  0.958074  0.958441  0.404958  0.045891
# 1256  0.937960  0.942574  0.950333  0.401844  0.029491
# 1257  0.936881  0.936691  0.934214  0.386726  0.070569
#
# [1258 rows x 5 columns]

# %%
data_scaled.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>],
#        [<Axes: title={'center': '4'}>, <Axes: >]], dtype=object)

# %%
numeric_data = data.select_dtypes(include=['number'])

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')

plt.show()

# %%
data_scaled=data_scaled.drop([1,2,4], axis=1)
data_scaled
# Out:
#              0         3
# 0     0.085814  0.237573
# 1     0.097012  0.241514
# 2     0.094334  0.228781
# 3     0.091562  0.216419
# 4     0.079842  0.178548
# ...        ...       ...
# 1253  0.952043  0.411656
# 1254  0.951633  0.413916
# 1255  0.957251  0.404958
# 1256  0.937960  0.401844
# 1257  0.936881  0.386726
#
# [1258 rows x 2 columns]

# %%
def split_seq_multivariate(sequence, n_past, n_future):

    '''
    n_past ==> no of past observations
    n_future ==> no of future observations
    '''
    x, y = [], []
    for window_start in range(len(sequence)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(sequence):
            break
        # slicing the past and future parts of the window
        past   = sequence[window_start:past_end, :]
        future = sequence[past_end:future_end, -1]
        x.append(past)
        y.append(future)

    return np.array(x), np.array(y)

# %%
# specify the window size
n_steps = 60

data_scaled = data_scaled.to_numpy()
data_scaled.shape
# Out:
# (1258, 2)

# %%
# split into samples
X, y = split_seq_multivariate(data_scaled, n_steps,1)

# %%
X[1].shape
# Out:
# (60, 2)

# %%
y
# Out:
# array([[0.21420007],
#        [0.20434657],
#        [0.21216047],
#        ...,
#        [0.40495845],
#        [0.40184391],
#        [0.38672602]])

# %%
# X is in the shape of [samples, timesteps, features]
print(X.shape)
print(y.shape)

# make y to the shape of [samples]
y=y[:,0]
y.shape
# Out:
# (1198, 60, 2)
# (1198, 1)
# (1198,)

# %%
# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=50)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (958, 60, 2) (240, 60, 2) (958,) (240,)

# %%
# define RNN model
model = Sequential()
model.add(LSTM(612, input_shape=(n_steps,2)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1))
# Out:
# 2026-03-25 13:18:15.657038: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/student/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 612)            │     1,505,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │        30,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,540,281 (5.88 MB)
#  Trainable params: 1,540,281 (5.88 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
history = model.fit(
    X_train, y_train,
    epochs=250,
    batch_size=32,
    verbose=2,
    validation_split=0.2   # 👈 automatically creates validation set
)
# Out:
# Epoch 1/250
# 24/24 - 9s - 366ms/step - loss: 0.0512 - mae: 0.1505 - val_loss: 0.0047 - val_mae: 0.0459
# Epoch 2/250
# 24/24 - 8s - 339ms/step - loss: 0.0048 - mae: 0.0374 - val_loss: 0.0018 - val_mae: 0.0264
# Epoch 3/250
# 24/24 - 8s - 343ms/step - loss: 0.0038 - mae: 0.0331 - val_loss: 0.0028 - val_mae: 0.0422
# Epoch 4/250
# 24/24 - 8s - 341ms/step - loss: 0.0034 - mae: 0.0302 - val_loss: 9.9339e-04 - val_mae: 0.0234
# Epoch 5/250
# 24/24 - 9s - 385ms/step - loss: 0.0031 - mae: 0.0275 - val_loss: 0.0010 - val_mae: 0.0246
# Epoch 6/250
# 24/24 - 9s - 355ms/step - loss: 0.0033 - mae: 0.0313 - val_loss: 0.0010 - val_mae: 0.0248
# Epoch 7/250
# 24/24 - 9s - 355ms/step - loss: 0.0027 - mae: 0.0249 - val_loss: 6.0967e-04 - val_mae: 0.0187
# Epoch 8/250
# 24/24 - 9s - 367ms/step - loss: 0.0019 - mae: 0.0199 - val_loss: 0.0020 - val_mae: 0.0325
# Epoch 9/250
# 24/24 - 9s - 383ms/step - loss: 0.0025 - mae: 0.0271 - val_loss: 6.3207e-04 - val_mae: 0.0189
# Epoch 10/250
# 24/24 - 9s - 356ms/step - loss: 0.0029 - mae: 0.0304 - val_loss: 4.9197e-04 - val_mae: 0.0173
# Epoch 11/250
# 24/24 - 9s - 361ms/step - loss: 0.0024 - mae: 0.0248 - val_loss: 5.4226e-04 - val_mae: 0.0175
# Epoch 12/250
# 24/24 - 9s - 356ms/step - loss: 0.0020 - mae: 0.0237 - val_loss: 0.0014 - val_mae: 0.0328
# Epoch 13/250
# 24/24 - 10s - 405ms/step - loss: 0.0022 - mae: 0.0259 - val_loss: 9.1124e-04 - val_mae: 0.0238
# Epoch 14/250
# 24/24 - 9s - 360ms/step - loss: 0.0021 - mae: 0.0234 - val_loss: 9.1061e-04 - val_mae: 0.0242
# Epoch 15/250
# 24/24 - 8s - 353ms/step - loss: 0.0017 - mae: 0.0208 - val_loss: 7.1991e-04 - val_mae: 0.0214
# Epoch 16/250
# 24/24 - 9s - 363ms/step - loss: 0.0018 - mae: 0.0214 - val_loss: 4.7627e-04 - val_mae: 0.0168
# Epoch 17/250
# 24/24 - 9s - 368ms/step - loss: 0.0020 - mae: 0.0195 - val_loss: 4.9043e-04 - val_mae: 0.0167
# Epoch 18/250
# 24/24 - 9s - 378ms/step - loss: 0.0017 - mae: 0.0194 - val_loss: 4.4767e-04 - val_mae: 0.0161
# Epoch 19/250
# 24/24 - 8s - 346ms/step - loss: 0.0014 - mae: 0.0181 - val_loss: 5.8916e-04 - val_mae: 0.0189
# Epoch 20/250
# 24/24 - 8s - 345ms/step - loss: 0.0016 - mae: 0.0209 - val_loss: 5.3425e-04 - val_mae: 0.0185
# Epoch 21/250
# 24/24 - 9s - 355ms/step - loss: 0.0014 - mae: 0.0193 - val_loss: 0.0010 - val_mae: 0.0257
# Epoch 22/250
# 24/24 - 8s - 345ms/step - loss: 0.0018 - mae: 0.0251 - val_loss: 5.9245e-04 - val_mae: 0.0186
# Epoch 23/250
# 24/24 - 8s - 340ms/step - loss: 0.0016 - mae: 0.0206 - val_loss: 5.5102e-04 - val_mae: 0.0177
# Epoch 24/250
# 24/24 - 8s - 337ms/step - loss: 0.0016 - mae: 0.0199 - val_loss: 6.0063e-04 - val_mae: 0.0191
# Epoch 25/250
# 24/24 - 8s - 342ms/step - loss: 0.0013 - mae: 0.0165 - val_loss: 6.9585e-04 - val_mae: 0.0215
# Epoch 26/250
# 24/24 - 9s - 369ms/step - loss: 0.0014 - mae: 0.0189 - val_loss: 8.9627e-04 - val_mae: 0.0249
# Epoch 27/250
# 24/24 - 8s - 330ms/step - loss: 0.0016 - mae: 0.0212 - val_loss: 4.0666e-04 - val_mae: 0.0152
# Epoch 28/250
# 24/24 - 7s - 312ms/step - loss: 0.0013 - mae: 0.0164 - val_loss: 3.9631e-04 - val_mae: 0.0151
# Epoch 29/250
# 24/24 - 7s - 306ms/step - loss: 0.0014 - mae: 0.0184 - val_loss: 4.1591e-04 - val_mae: 0.0159
# Epoch 30/250
# 24/24 - 7s - 306ms/step - loss: 0.0014 - mae: 0.0195 - val_loss: 4.2908e-04 - val_mae: 0.0157
# Epoch 31/250
# 24/24 - 7s - 304ms/step - loss: 0.0013 - mae: 0.0180 - val_loss: 4.1002e-04 - val_mae: 0.0162
# Epoch 32/250
# 24/24 - 8s - 318ms/step - loss: 0.0013 - mae: 0.0170 - val_loss: 3.4342e-04 - val_mae: 0.0143
# Epoch 33/250
# 24/24 - 7s - 305ms/step - loss: 0.0013 - mae: 0.0165 - val_loss: 3.5960e-04 - val_mae: 0.0145
# Epoch 34/250
# 24/24 - 7s - 310ms/step - loss: 0.0013 - mae: 0.0190 - val_loss: 6.5627e-04 - val_mae: 0.0198
# Epoch 35/250
# 24/24 - 7s - 304ms/step - loss: 0.0014 - mae: 0.0191 - val_loss: 3.7580e-04 - val_mae: 0.0147
# Epoch 36/250
# 24/24 - 7s - 307ms/step - loss: 0.0014 - mae: 0.0181 - val_loss: 6.2866e-04 - val_mae: 0.0207
# Epoch 37/250
# 24/24 - 7s - 309ms/step - loss: 0.0016 - mae: 0.0210 - val_loss: 5.0639e-04 - val_mae: 0.0183
# Epoch 38/250
# 24/24 - 7s - 305ms/step - loss: 0.0012 - mae: 0.0161 - val_loss: 4.6708e-04 - val_mae: 0.0162
# Epoch 39/250
# 24/24 - 7s - 306ms/step - loss: 0.0012 - mae: 0.0158 - val_loss: 3.2927e-04 - val_mae: 0.0136
# Epoch 40/250
# 24/24 - 7s - 303ms/step - loss: 0.0012 - mae: 0.0161 - val_loss: 5.3694e-04 - val_mae: 0.0184
# Epoch 41/250
# 24/24 - 7s - 311ms/step - loss: 0.0014 - mae: 0.0205 - val_loss: 5.5015e-04 - val_mae: 0.0183
# Epoch 42/250
# 24/24 - 7s - 305ms/step - loss: 0.0013 - mae: 0.0174 - val_loss: 3.1690e-04 - val_mae: 0.0135
# Epoch 43/250
# 24/24 - 7s - 305ms/step - loss: 0.0012 - mae: 0.0162 - val_loss: 3.1956e-04 - val_mae: 0.0132
# Epoch 44/250
# 24/24 - 7s - 303ms/step - loss: 0.0013 - mae: 0.0171 - val_loss: 3.4720e-04 - val_mae: 0.0141
# Epoch 45/250
# 24/24 - 8s - 315ms/step - loss: 0.0012 - mae: 0.0144 - val_loss: 5.2909e-04 - val_mae: 0.0179
# Epoch 46/250
# 24/24 - 7s - 309ms/step - loss: 0.0013 - mae: 0.0169 - val_loss: 7.8317e-04 - val_mae: 0.0231
# Epoch 47/250
# 24/24 - 7s - 304ms/step - loss: 0.0013 - mae: 0.0186 - val_loss: 3.2191e-04 - val_mae: 0.0138
# Epoch 48/250
# 24/24 - 7s - 305ms/step - loss: 0.0013 - mae: 0.0163 - val_loss: 4.3959e-04 - val_mae: 0.0168
# Epoch 49/250
# 24/24 - 7s - 306ms/step - loss: 0.0015 - mae: 0.0190 - val_loss: 3.3777e-04 - val_mae: 0.0141
# Epoch 50/250
# 24/24 - 7s - 310ms/step - loss: 0.0013 - mae: 0.0158 - val_loss: 5.4930e-04 - val_mae: 0.0187
# Epoch 51/250
# 24/24 - 7s - 305ms/step - loss: 0.0013 - mae: 0.0158 - val_loss: 4.3162e-04 - val_mae: 0.0158
# Epoch 52/250
# 24/24 - 7s - 305ms/step - loss: 0.0012 - mae: 0.0163 - val_loss: 5.1965e-04 - val_mae: 0.0178
# Epoch 53/250
# 24/24 - 8s - 320ms/step - loss: 0.0013 - mae: 0.0169 - val_loss: 4.8565e-04 - val_mae: 0.0170
# Epoch 54/250
# 24/24 - 7s - 306ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 3.4308e-04 - val_mae: 0.0142
# Epoch 55/250
# 24/24 - 7s - 305ms/step - loss: 0.0013 - mae: 0.0155 - val_loss: 3.6640e-04 - val_mae: 0.0151
# Epoch 56/250
# 24/24 - 7s - 303ms/step - loss: 0.0012 - mae: 0.0150 - val_loss: 5.4492e-04 - val_mae: 0.0183
# Epoch 57/250
# 24/24 - 7s - 303ms/step - loss: 0.0012 - mae: 0.0166 - val_loss: 3.1170e-04 - val_mae: 0.0136
# Epoch 58/250
# 24/24 - 8s - 314ms/step - loss: 0.0013 - mae: 0.0167 - val_loss: 4.8990e-04 - val_mae: 0.0170
# Epoch 59/250
# 24/24 - 7s - 311ms/step - loss: 0.0012 - mae: 0.0147 - val_loss: 5.0594e-04 - val_mae: 0.0173
# Epoch 60/250
# 24/24 - 7s - 308ms/step - loss: 0.0012 - mae: 0.0178 - val_loss: 3.3231e-04 - val_mae: 0.0137
# Epoch 61/250
# 24/24 - 7s - 307ms/step - loss: 0.0012 - mae: 0.0151 - val_loss: 4.0021e-04 - val_mae: 0.0148
# Epoch 62/250
# 24/24 - 7s - 305ms/step - loss: 0.0011 - mae: 0.0149 - val_loss: 3.0197e-04 - val_mae: 0.0128
# Epoch 63/250
# 24/24 - 8s - 324ms/step - loss: 0.0011 - mae: 0.0135 - val_loss: 7.9075e-04 - val_mae: 0.0217
# Epoch 64/250
# 24/24 - 8s - 316ms/step - loss: 0.0015 - mae: 0.0206 - val_loss: 6.8533e-04 - val_mae: 0.0216
# Epoch 65/250
# 24/24 - 8s - 313ms/step - loss: 0.0012 - mae: 0.0171 - val_loss: 7.4024e-04 - val_mae: 0.0226
# Epoch 66/250
# 24/24 - 8s - 318ms/step - loss: 0.0012 - mae: 0.0169 - val_loss: 5.5793e-04 - val_mae: 0.0183
# Epoch 67/250
# 24/24 - 8s - 317ms/step - loss: 0.0013 - mae: 0.0173 - val_loss: 3.5814e-04 - val_mae: 0.0153
# Epoch 68/250
# 24/24 - 7s - 311ms/step - loss: 0.0011 - mae: 0.0151 - val_loss: 2.7237e-04 - val_mae: 0.0122
# Epoch 69/250
# 24/24 - 8s - 316ms/step - loss: 0.0012 - mae: 0.0151 - val_loss: 2.9706e-04 - val_mae: 0.0129
# Epoch 70/250
# 24/24 - 7s - 307ms/step - loss: 0.0012 - mae: 0.0159 - val_loss: 3.1203e-04 - val_mae: 0.0139
# Epoch 71/250
# 24/24 - 7s - 311ms/step - loss: 0.0013 - mae: 0.0182 - val_loss: 3.2403e-04 - val_mae: 0.0136
# Epoch 72/250
# 24/24 - 7s - 309ms/step - loss: 0.0012 - mae: 0.0145 - val_loss: 5.7237e-04 - val_mae: 0.0193
# Epoch 73/250
# 24/24 - 8s - 314ms/step - loss: 0.0013 - mae: 0.0177 - val_loss: 3.3909e-04 - val_mae: 0.0139
# Epoch 74/250
# 24/24 - 8s - 324ms/step - loss: 0.0012 - mae: 0.0161 - val_loss: 5.1437e-04 - val_mae: 0.0175
# Epoch 75/250
# 24/24 - 8s - 328ms/step - loss: 0.0013 - mae: 0.0188 - val_loss: 2.7631e-04 - val_mae: 0.0125
# Epoch 76/250
# 24/24 - 8s - 314ms/step - loss: 0.0012 - mae: 0.0148 - val_loss: 2.8562e-04 - val_mae: 0.0131
# Epoch 77/250
# 24/24 - 7s - 311ms/step - loss: 0.0013 - mae: 0.0167 - val_loss: 2.8850e-04 - val_mae: 0.0127
# Epoch 78/250
# 24/24 - 7s - 310ms/step - loss: 0.0013 - mae: 0.0177 - val_loss: 2.7795e-04 - val_mae: 0.0125
# Epoch 79/250
# 24/24 - 7s - 311ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 3.5391e-04 - val_mae: 0.0143
# Epoch 80/250
# 24/24 - 7s - 312ms/step - loss: 0.0013 - mae: 0.0170 - val_loss: 4.3241e-04 - val_mae: 0.0169
# Epoch 81/250
# 24/24 - 7s - 309ms/step - loss: 0.0013 - mae: 0.0172 - val_loss: 3.3966e-04 - val_mae: 0.0146
# Epoch 82/250
# 24/24 - 7s - 312ms/step - loss: 0.0012 - mae: 0.0173 - val_loss: 2.6274e-04 - val_mae: 0.0121
# Epoch 83/250
# 24/24 - 8s - 330ms/step - loss: 0.0012 - mae: 0.0149 - val_loss: 3.0313e-04 - val_mae: 0.0137
# Epoch 84/250
# 24/24 - 8s - 316ms/step - loss: 0.0012 - mae: 0.0152 - val_loss: 2.6854e-04 - val_mae: 0.0125
# Epoch 85/250
# 24/24 - 8s - 319ms/step - loss: 0.0011 - mae: 0.0124 - val_loss: 3.3742e-04 - val_mae: 0.0145
# Epoch 86/250
# 24/24 - 7s - 312ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 5.5784e-04 - val_mae: 0.0191
# Epoch 87/250
# 24/24 - 7s - 312ms/step - loss: 0.0013 - mae: 0.0178 - val_loss: 3.2138e-04 - val_mae: 0.0133
# Epoch 88/250
# 24/24 - 8s - 314ms/step - loss: 0.0011 - mae: 0.0145 - val_loss: 6.8503e-04 - val_mae: 0.0215
# Epoch 89/250
# 24/24 - 7s - 311ms/step - loss: 0.0013 - mae: 0.0172 - val_loss: 5.7701e-04 - val_mae: 0.0194
# Epoch 90/250
# 24/24 - 7s - 309ms/step - loss: 0.0012 - mae: 0.0143 - val_loss: 3.1821e-04 - val_mae: 0.0136
# Epoch 91/250
# 24/24 - 8s - 329ms/step - loss: 0.0013 - mae: 0.0178 - val_loss: 3.8700e-04 - val_mae: 0.0158
# Epoch 92/250
# 24/24 - 8s - 315ms/step - loss: 0.0012 - mae: 0.0166 - val_loss: 3.4740e-04 - val_mae: 0.0145
# Epoch 93/250
# 24/24 - 8s - 318ms/step - loss: 0.0011 - mae: 0.0142 - val_loss: 2.6146e-04 - val_mae: 0.0122
# Epoch 94/250
# 24/24 - 8s - 343ms/step - loss: 0.0012 - mae: 0.0143 - val_loss: 3.5732e-04 - val_mae: 0.0151
# Epoch 95/250
# 24/24 - 8s - 329ms/step - loss: 0.0012 - mae: 0.0159 - val_loss: 2.5262e-04 - val_mae: 0.0121
# Epoch 96/250
# 24/24 - 8s - 345ms/step - loss: 0.0012 - mae: 0.0163 - val_loss: 3.4681e-04 - val_mae: 0.0141
# Epoch 97/250
# 24/24 - 8s - 322ms/step - loss: 0.0012 - mae: 0.0154 - val_loss: 3.4692e-04 - val_mae: 0.0143
# Epoch 98/250
# 24/24 - 8s - 338ms/step - loss: 0.0011 - mae: 0.0135 - val_loss: 5.4795e-04 - val_mae: 0.0190
# Epoch 99/250
# 24/24 - 7s - 304ms/step - loss: 0.0014 - mae: 0.0204 - val_loss: 8.4377e-04 - val_mae: 0.0245
# Epoch 100/250
# 24/24 - 8s - 353ms/step - loss: 0.0012 - mae: 0.0172 - val_loss: 3.2396e-04 - val_mae: 0.0136
# Epoch 101/250
# 24/24 - 8s - 333ms/step - loss: 0.0011 - mae: 0.0142 - val_loss: 5.5960e-04 - val_mae: 0.0183
# Epoch 102/250
# 24/24 - 8s - 337ms/step - loss: 0.0013 - mae: 0.0171 - val_loss: 3.6910e-04 - val_mae: 0.0157
# Epoch 103/250
# 24/24 - 9s - 361ms/step - loss: 0.0011 - mae: 0.0137 - val_loss: 3.0880e-04 - val_mae: 0.0134
# Epoch 104/250
# 24/24 - 8s - 342ms/step - loss: 0.0012 - mae: 0.0160 - val_loss: 5.0094e-04 - val_mae: 0.0175
# Epoch 105/250
# 24/24 - 8s - 341ms/step - loss: 0.0011 - mae: 0.0150 - val_loss: 2.9122e-04 - val_mae: 0.0130
# Epoch 106/250
# 24/24 - 8s - 347ms/step - loss: 0.0012 - mae: 0.0158 - val_loss: 2.3705e-04 - val_mae: 0.0115
# Epoch 107/250
# 24/24 - 8s - 344ms/step - loss: 0.0012 - mae: 0.0165 - val_loss: 5.1229e-04 - val_mae: 0.0191
# Epoch 108/250
# 24/24 - 8s - 345ms/step - loss: 0.0011 - mae: 0.0152 - val_loss: 4.3421e-04 - val_mae: 0.0163
# Epoch 109/250
# 24/24 - 8s - 338ms/step - loss: 0.0011 - mae: 0.0141 - val_loss: 2.7375e-04 - val_mae: 0.0132
# Epoch 110/250
# 24/24 - 8s - 319ms/step - loss: 0.0011 - mae: 0.0147 - val_loss: 2.4570e-04 - val_mae: 0.0117
# Epoch 111/250
# 24/24 - 8s - 351ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 2.8494e-04 - val_mae: 0.0128
# Epoch 112/250
# 24/24 - 8s - 352ms/step - loss: 0.0012 - mae: 0.0157 - val_loss: 2.4495e-04 - val_mae: 0.0121
# Epoch 113/250
# 24/24 - 9s - 372ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 5.0923e-04 - val_mae: 0.0183
# Epoch 114/250
# 24/24 - 8s - 351ms/step - loss: 0.0014 - mae: 0.0196 - val_loss: 6.2870e-04 - val_mae: 0.0204
# Epoch 115/250
# 24/24 - 8s - 346ms/step - loss: 0.0013 - mae: 0.0160 - val_loss: 3.0393e-04 - val_mae: 0.0132
# Epoch 116/250
# 24/24 - 8s - 348ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 2.4041e-04 - val_mae: 0.0118
# Epoch 117/250
# 24/24 - 8s - 347ms/step - loss: 0.0011 - mae: 0.0138 - val_loss: 3.2849e-04 - val_mae: 0.0139
# Epoch 118/250
# 24/24 - 9s - 360ms/step - loss: 0.0013 - mae: 0.0189 - val_loss: 2.8758e-04 - val_mae: 0.0126
# Epoch 119/250
# 24/24 - 8s - 345ms/step - loss: 0.0011 - mae: 0.0137 - val_loss: 2.7873e-04 - val_mae: 0.0126
# Epoch 120/250
# 24/24 - 8s - 321ms/step - loss: 0.0012 - mae: 0.0149 - val_loss: 2.4546e-04 - val_mae: 0.0124
# Epoch 121/250
# 24/24 - 8s - 336ms/step - loss: 0.0012 - mae: 0.0154 - val_loss: 3.8307e-04 - val_mae: 0.0161
# Epoch 122/250
# 24/24 - 8s - 342ms/step - loss: 0.0012 - mae: 0.0151 - val_loss: 6.2605e-04 - val_mae: 0.0197
# Epoch 123/250
# 24/24 - 9s - 361ms/step - loss: 0.0013 - mae: 0.0180 - val_loss: 4.2766e-04 - val_mae: 0.0164
# Epoch 124/250
# 24/24 - 8s - 341ms/step - loss: 0.0012 - mae: 0.0171 - val_loss: 4.0998e-04 - val_mae: 0.0162
# Epoch 125/250
# 24/24 - 9s - 360ms/step - loss: 0.0014 - mae: 0.0183 - val_loss: 2.6142e-04 - val_mae: 0.0122
# Epoch 126/250
# 24/24 - 8s - 351ms/step - loss: 0.0012 - mae: 0.0150 - val_loss: 2.7971e-04 - val_mae: 0.0135
# Epoch 127/250
# 24/24 - 8s - 340ms/step - loss: 0.0011 - mae: 0.0128 - val_loss: 3.7110e-04 - val_mae: 0.0158
# Epoch 128/250
# 24/24 - 8s - 350ms/step - loss: 0.0011 - mae: 0.0138 - val_loss: 4.5198e-04 - val_mae: 0.0165
# Epoch 129/250
# 24/24 - 9s - 370ms/step - loss: 0.0012 - mae: 0.0152 - val_loss: 4.2001e-04 - val_mae: 0.0165
# Epoch 130/250
# 24/24 - 8s - 330ms/step - loss: 0.0011 - mae: 0.0142 - val_loss: 2.4825e-04 - val_mae: 0.0122
# Epoch 131/250
# 24/24 - 8s - 338ms/step - loss: 0.0011 - mae: 0.0130 - val_loss: 4.4866e-04 - val_mae: 0.0172
# Epoch 132/250
# 24/24 - 8s - 345ms/step - loss: 0.0011 - mae: 0.0151 - val_loss: 3.5650e-04 - val_mae: 0.0148
# Epoch 133/250
# 24/24 - 8s - 347ms/step - loss: 0.0011 - mae: 0.0127 - val_loss: 2.5574e-04 - val_mae: 0.0124
# Epoch 134/250
# 24/24 - 8s - 350ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 2.2742e-04 - val_mae: 0.0117
# Epoch 135/250
# 24/24 - 8s - 336ms/step - loss: 0.0013 - mae: 0.0163 - val_loss: 2.6361e-04 - val_mae: 0.0134
# Epoch 136/250
# 24/24 - 8s - 343ms/step - loss: 0.0013 - mae: 0.0166 - val_loss: 2.4029e-04 - val_mae: 0.0119
# Epoch 137/250
# 24/24 - 9s - 362ms/step - loss: 0.0011 - mae: 0.0145 - val_loss: 2.4271e-04 - val_mae: 0.0123
# Epoch 138/250
# 24/24 - 8s - 353ms/step - loss: 0.0011 - mae: 0.0140 - val_loss: 3.2401e-04 - val_mae: 0.0139
# Epoch 139/250
# 24/24 - 8s - 345ms/step - loss: 0.0013 - mae: 0.0171 - val_loss: 2.7204e-04 - val_mae: 0.0127
# Epoch 140/250
# 24/24 - 9s - 377ms/step - loss: 0.0012 - mae: 0.0148 - val_loss: 1.9643e-04 - val_mae: 0.0104
# Epoch 141/250
# 24/24 - 8s - 351ms/step - loss: 0.0011 - mae: 0.0137 - val_loss: 3.5162e-04 - val_mae: 0.0150
# Epoch 142/250
# 24/24 - 9s - 376ms/step - loss: 0.0011 - mae: 0.0132 - val_loss: 2.0512e-04 - val_mae: 0.0110
# Epoch 143/250
# 24/24 - 9s - 393ms/step - loss: 0.0012 - mae: 0.0148 - val_loss: 2.9628e-04 - val_mae: 0.0135
# Epoch 144/250
# 24/24 - 10s - 407ms/step - loss: 0.0011 - mae: 0.0134 - val_loss: 3.1869e-04 - val_mae: 0.0143
# Epoch 145/250
# 24/24 - 9s - 391ms/step - loss: 0.0013 - mae: 0.0173 - val_loss: 2.8342e-04 - val_mae: 0.0136
# Epoch 146/250
# 24/24 - 10s - 396ms/step - loss: 0.0011 - mae: 0.0150 - val_loss: 3.6828e-04 - val_mae: 0.0153
# Epoch 147/250
# 24/24 - 9s - 366ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 3.6606e-04 - val_mae: 0.0153
# Epoch 148/250
# 24/24 - 11s - 448ms/step - loss: 0.0012 - mae: 0.0151 - val_loss: 2.1840e-04 - val_mae: 0.0116
# Epoch 149/250
# 24/24 - 9s - 366ms/step - loss: 0.0012 - mae: 0.0163 - val_loss: 1.8296e-04 - val_mae: 0.0102
# Epoch 150/250
# 24/24 - 8s - 349ms/step - loss: 0.0011 - mae: 0.0125 - val_loss: 4.2028e-04 - val_mae: 0.0164
# Epoch 151/250
# 24/24 - 9s - 357ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 2.4913e-04 - val_mae: 0.0128
# Epoch 152/250
# 24/24 - 8s - 344ms/step - loss: 0.0012 - mae: 0.0149 - val_loss: 2.3007e-04 - val_mae: 0.0115
# Epoch 153/250
# 24/24 - 8s - 337ms/step - loss: 0.0011 - mae: 0.0138 - val_loss: 2.0514e-04 - val_mae: 0.0112
# Epoch 154/250
# 24/24 - 9s - 362ms/step - loss: 0.0011 - mae: 0.0130 - val_loss: 4.6250e-04 - val_mae: 0.0179
# Epoch 155/250
# 24/24 - 9s - 361ms/step - loss: 0.0011 - mae: 0.0153 - val_loss: 3.6235e-04 - val_mae: 0.0149
# Epoch 156/250
# 24/24 - 8s - 353ms/step - loss: 0.0013 - mae: 0.0192 - val_loss: 1.8882e-04 - val_mae: 0.0104
# Epoch 157/250
# 24/24 - 9s - 364ms/step - loss: 0.0012 - mae: 0.0143 - val_loss: 3.4816e-04 - val_mae: 0.0149
# Epoch 158/250
# 24/24 - 8s - 347ms/step - loss: 0.0011 - mae: 0.0136 - val_loss: 2.2181e-04 - val_mae: 0.0113
# Epoch 159/250
# 24/24 - 9s - 356ms/step - loss: 0.0013 - mae: 0.0191 - val_loss: 5.9215e-04 - val_mae: 0.0203
# Epoch 160/250
# 24/24 - 9s - 364ms/step - loss: 0.0015 - mae: 0.0222 - val_loss: 4.1623e-04 - val_mae: 0.0170
# Epoch 161/250
# 24/24 - 8s - 349ms/step - loss: 0.0011 - mae: 0.0141 - val_loss: 1.9518e-04 - val_mae: 0.0104
# Epoch 162/250
# 24/24 - 9s - 360ms/step - loss: 0.0011 - mae: 0.0124 - val_loss: 5.3917e-04 - val_mae: 0.0191
# Epoch 163/250
# 24/24 - 8s - 347ms/step - loss: 0.0012 - mae: 0.0154 - val_loss: 2.4384e-04 - val_mae: 0.0118
# Epoch 164/250
# 24/24 - 8s - 354ms/step - loss: 0.0011 - mae: 0.0132 - val_loss: 2.1686e-04 - val_mae: 0.0111
# Epoch 165/250
# 24/24 - 9s - 359ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 2.4704e-04 - val_mae: 0.0119
# Epoch 166/250
# 24/24 - 9s - 355ms/step - loss: 0.0012 - mae: 0.0150 - val_loss: 3.9094e-04 - val_mae: 0.0154
# Epoch 167/250
# 24/24 - 9s - 358ms/step - loss: 0.0011 - mae: 0.0142 - val_loss: 3.4475e-04 - val_mae: 0.0146
# Epoch 168/250
# 24/24 - 9s - 355ms/step - loss: 0.0012 - mae: 0.0159 - val_loss: 2.5443e-04 - val_mae: 0.0126
# Epoch 169/250
# 24/24 - 9s - 356ms/step - loss: 0.0011 - mae: 0.0143 - val_loss: 4.3379e-04 - val_mae: 0.0169
# Epoch 170/250
# 24/24 - 9s - 356ms/step - loss: 0.0011 - mae: 0.0140 - val_loss: 2.2711e-04 - val_mae: 0.0113
# Epoch 171/250
# 24/24 - 8s - 327ms/step - loss: 0.0011 - mae: 0.0153 - val_loss: 4.1385e-04 - val_mae: 0.0172
# Epoch 172/250
# 24/24 - 8s - 347ms/step - loss: 0.0011 - mae: 0.0143 - val_loss: 2.2013e-04 - val_mae: 0.0114
# Epoch 173/250
# 24/24 - 8s - 351ms/step - loss: 0.0011 - mae: 0.0133 - val_loss: 4.1174e-04 - val_mae: 0.0167
# Epoch 174/250
# 24/24 - 8s - 341ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 2.0091e-04 - val_mae: 0.0105
# Epoch 175/250
# 24/24 - 9s - 360ms/step - loss: 0.0011 - mae: 0.0147 - val_loss: 2.9923e-04 - val_mae: 0.0141
# Epoch 176/250
# 24/24 - 8s - 316ms/step - loss: 0.0011 - mae: 0.0128 - val_loss: 6.4065e-04 - val_mae: 0.0207
# Epoch 177/250
# 24/24 - 7s - 304ms/step - loss: 0.0012 - mae: 0.0159 - val_loss: 4.0459e-04 - val_mae: 0.0164
# Epoch 178/250
# 24/24 - 7s - 305ms/step - loss: 0.0012 - mae: 0.0169 - val_loss: 2.4896e-04 - val_mae: 0.0124
# Epoch 179/250
# 24/24 - 7s - 305ms/step - loss: 0.0012 - mae: 0.0182 - val_loss: 3.6512e-04 - val_mae: 0.0151
# Epoch 180/250
# 24/24 - 7s - 303ms/step - loss: 0.0013 - mae: 0.0184 - val_loss: 2.8059e-04 - val_mae: 0.0127
# Epoch 181/250
# 24/24 - 7s - 305ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 1.9449e-04 - val_mae: 0.0106
# Epoch 182/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0141 - val_loss: 2.3077e-04 - val_mae: 0.0118
# Epoch 183/250
# 24/24 - 7s - 305ms/step - loss: 0.0011 - mae: 0.0156 - val_loss: 2.3054e-04 - val_mae: 0.0116
# Epoch 184/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0151 - val_loss: 3.3207e-04 - val_mae: 0.0139
# Epoch 185/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0144 - val_loss: 2.0279e-04 - val_mae: 0.0105
# Epoch 186/250
# 24/24 - 7s - 306ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 3.9805e-04 - val_mae: 0.0169
# Epoch 187/250
# 24/24 - 7s - 304ms/step - loss: 0.0011 - mae: 0.0151 - val_loss: 1.9416e-04 - val_mae: 0.0102
# Epoch 188/250
# 24/24 - 7s - 309ms/step - loss: 0.0014 - mae: 0.0200 - val_loss: 2.9397e-04 - val_mae: 0.0139
# Epoch 189/250
# 24/24 - 7s - 303ms/step - loss: 0.0012 - mae: 0.0143 - val_loss: 2.8664e-04 - val_mae: 0.0131
# Epoch 190/250
# 24/24 - 7s - 300ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 2.2949e-04 - val_mae: 0.0113
# Epoch 191/250
# 24/24 - 7s - 306ms/step - loss: 9.8173e-04 - mae: 0.0118 - val_loss: 2.4801e-04 - val_mae: 0.0124
# Epoch 192/250
# 24/24 - 7s - 301ms/step - loss: 0.0013 - mae: 0.0197 - val_loss: 2.2102e-04 - val_mae: 0.0113
# Epoch 193/250
# 24/24 - 7s - 308ms/step - loss: 0.0011 - mae: 0.0131 - val_loss: 3.1565e-04 - val_mae: 0.0138
# Epoch 194/250
# 24/24 - 7s - 304ms/step - loss: 0.0011 - mae: 0.0146 - val_loss: 2.0878e-04 - val_mae: 0.0107
# Epoch 195/250
# 24/24 - 7s - 311ms/step - loss: 0.0011 - mae: 0.0159 - val_loss: 3.1786e-04 - val_mae: 0.0137
# Epoch 196/250
# 24/24 - 7s - 304ms/step - loss: 9.9385e-04 - mae: 0.0121 - val_loss: 2.6148e-04 - val_mae: 0.0127
# Epoch 197/250
# 24/24 - 7s - 310ms/step - loss: 0.0013 - mae: 0.0182 - val_loss: 2.1716e-04 - val_mae: 0.0110
# Epoch 198/250
# 24/24 - 7s - 304ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 2.2470e-04 - val_mae: 0.0113
# Epoch 199/250
# 24/24 - 7s - 301ms/step - loss: 0.0012 - mae: 0.0155 - val_loss: 2.1688e-04 - val_mae: 0.0116
# Epoch 200/250
# 24/24 - 7s - 304ms/step - loss: 0.0011 - mae: 0.0138 - val_loss: 4.7905e-04 - val_mae: 0.0169
# Epoch 201/250
# 24/24 - 7s - 304ms/step - loss: 0.0013 - mae: 0.0208 - val_loss: 2.9499e-04 - val_mae: 0.0129
# Epoch 202/250
# 24/24 - 7s - 304ms/step - loss: 0.0012 - mae: 0.0153 - val_loss: 2.1436e-04 - val_mae: 0.0111
# Epoch 203/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0150 - val_loss: 2.1991e-04 - val_mae: 0.0110
# Epoch 204/250
# 24/24 - 7s - 308ms/step - loss: 0.0010 - mae: 0.0127 - val_loss: 2.4013e-04 - val_mae: 0.0115
# Epoch 205/250
# 24/24 - 7s - 307ms/step - loss: 0.0011 - mae: 0.0137 - val_loss: 2.3652e-04 - val_mae: 0.0115
# Epoch 206/250
# 24/24 - 7s - 307ms/step - loss: 0.0011 - mae: 0.0150 - val_loss: 4.0135e-04 - val_mae: 0.0160
# Epoch 207/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 1.7101e-04 - val_mae: 0.0096
# Epoch 208/250
# 24/24 - 7s - 306ms/step - loss: 0.0012 - mae: 0.0167 - val_loss: 2.1894e-04 - val_mae: 0.0114
# Epoch 209/250
# 24/24 - 7s - 305ms/step - loss: 0.0011 - mae: 0.0151 - val_loss: 2.5109e-04 - val_mae: 0.0122
# Epoch 210/250
# 24/24 - 7s - 304ms/step - loss: 0.0011 - mae: 0.0144 - val_loss: 1.8838e-04 - val_mae: 0.0102
# Epoch 211/250
# 24/24 - 7s - 307ms/step - loss: 0.0011 - mae: 0.0131 - val_loss: 2.2799e-04 - val_mae: 0.0113
# Epoch 212/250
# 24/24 - 7s - 309ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 2.2924e-04 - val_mae: 0.0120
# Epoch 213/250
# 24/24 - 8s - 316ms/step - loss: 0.0012 - mae: 0.0147 - val_loss: 1.8078e-04 - val_mae: 0.0099
# Epoch 214/250
# 24/24 - 7s - 312ms/step - loss: 0.0011 - mae: 0.0140 - val_loss: 2.4209e-04 - val_mae: 0.0120
# Epoch 215/250
# 24/24 - 7s - 304ms/step - loss: 0.0011 - mae: 0.0145 - val_loss: 1.7494e-04 - val_mae: 0.0097
# Epoch 216/250
# 24/24 - 7s - 306ms/step - loss: 0.0011 - mae: 0.0134 - val_loss: 2.7942e-04 - val_mae: 0.0135
# Epoch 217/250
# 24/24 - 8s - 318ms/step - loss: 0.0011 - mae: 0.0136 - val_loss: 3.8242e-04 - val_mae: 0.0161
# Epoch 218/250
# 24/24 - 8s - 324ms/step - loss: 0.0012 - mae: 0.0164 - val_loss: 1.9207e-04 - val_mae: 0.0106
# Epoch 219/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0138 - val_loss: 3.0392e-04 - val_mae: 0.0138
# Epoch 220/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0148 - val_loss: 2.8242e-04 - val_mae: 0.0133
# Epoch 221/250
# 24/24 - 7s - 300ms/step - loss: 0.0011 - mae: 0.0132 - val_loss: 1.9966e-04 - val_mae: 0.0107
# Epoch 222/250
# 24/24 - 7s - 300ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 3.5174e-04 - val_mae: 0.0150
# Epoch 223/250
# 24/24 - 7s - 300ms/step - loss: 0.0011 - mae: 0.0146 - val_loss: 1.8975e-04 - val_mae: 0.0106
# Epoch 224/250
# 24/24 - 7s - 300ms/step - loss: 0.0011 - mae: 0.0143 - val_loss: 2.0826e-04 - val_mae: 0.0110
# Epoch 225/250
# 24/24 - 7s - 309ms/step - loss: 0.0011 - mae: 0.0159 - val_loss: 2.5097e-04 - val_mae: 0.0123
# Epoch 226/250
# 24/24 - 7s - 311ms/step - loss: 0.0010 - mae: 0.0136 - val_loss: 3.4950e-04 - val_mae: 0.0144
# Epoch 227/250
# 24/24 - 7s - 304ms/step - loss: 0.0012 - mae: 0.0179 - val_loss: 2.9880e-04 - val_mae: 0.0140
# Epoch 228/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0152 - val_loss: 5.0464e-04 - val_mae: 0.0188
# Epoch 229/250
# 24/24 - 7s - 302ms/step - loss: 0.0012 - mae: 0.0180 - val_loss: 3.6328e-04 - val_mae: 0.0150
# Epoch 230/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0150 - val_loss: 4.6464e-04 - val_mae: 0.0173
# Epoch 231/250
# 24/24 - 7s - 299ms/step - loss: 0.0011 - mae: 0.0154 - val_loss: 3.0718e-04 - val_mae: 0.0142
# Epoch 232/250
# 24/24 - 7s - 303ms/step - loss: 0.0010 - mae: 0.0128 - val_loss: 3.7229e-04 - val_mae: 0.0154
# Epoch 233/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0147 - val_loss: 4.2373e-04 - val_mae: 0.0167
# Epoch 234/250
# 24/24 - 7s - 299ms/step - loss: 0.0011 - mae: 0.0158 - val_loss: 1.7295e-04 - val_mae: 0.0095
# Epoch 235/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0148 - val_loss: 1.8440e-04 - val_mae: 0.0101
# Epoch 236/250
# 24/24 - 7s - 300ms/step - loss: 0.0011 - mae: 0.0134 - val_loss: 3.2022e-04 - val_mae: 0.0143
# Epoch 237/250
# 24/24 - 7s - 301ms/step - loss: 0.0010 - mae: 0.0134 - val_loss: 3.7855e-04 - val_mae: 0.0159
# Epoch 238/250
# 24/24 - 7s - 301ms/step - loss: 0.0011 - mae: 0.0158 - val_loss: 1.9235e-04 - val_mae: 0.0103
# Epoch 239/250
# 24/24 - 7s - 301ms/step - loss: 0.0010 - mae: 0.0128 - val_loss: 3.1914e-04 - val_mae: 0.0138
# Epoch 240/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0139 - val_loss: 3.4332e-04 - val_mae: 0.0148
# Epoch 241/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0137 - val_loss: 3.5184e-04 - val_mae: 0.0151
# Epoch 242/250
# 24/24 - 7s - 302ms/step - loss: 0.0012 - mae: 0.0152 - val_loss: 2.0093e-04 - val_mae: 0.0104
# Epoch 243/250
# 24/24 - 7s - 306ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 2.2273e-04 - val_mae: 0.0119
# Epoch 244/250
# 24/24 - 7s - 311ms/step - loss: 0.0011 - mae: 0.0136 - val_loss: 3.5876e-04 - val_mae: 0.0148
# Epoch 245/250
# 24/24 - 7s - 306ms/step - loss: 0.0011 - mae: 0.0147 - val_loss: 1.9911e-04 - val_mae: 0.0104
# Epoch 246/250
# 24/24 - 7s - 312ms/step - loss: 0.0011 - mae: 0.0146 - val_loss: 2.3508e-04 - val_mae: 0.0123
# Epoch 247/250
# 24/24 - 7s - 302ms/step - loss: 0.0011 - mae: 0.0158 - val_loss: 3.2547e-04 - val_mae: 0.0147
# Epoch 248/250
# 24/24 - 7s - 301ms/step - loss: 0.0010 - mae: 0.0145 - val_loss: 1.7458e-04 - val_mae: 0.0097
# Epoch 249/250
# 24/24 - 7s - 303ms/step - loss: 0.0011 - mae: 0.0135 - val_loss: 2.8150e-04 - val_mae: 0.0131
# Epoch 250/250
# 24/24 - 7s - 306ms/step - loss: 0.0011 - mae: 0.0153 - val_loss: 1.8611e-04 - val_mae: 0.0102

# %%
from matplotlib import pyplot
# plot learning curves
pyplot.title('Learning Curves')
pyplot.xlabel('Epoch')
pyplot.ylabel('Root Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()

# %%
# evaluate the model
mse, mae = model.evaluate(X_test, y_test, verbose=0)
print('MSE: %.3f, RMSE: %.3f, MAE: %.3f' % (mse, np.sqrt(mse), mae))
# Out:
# MSE: 0.000, RMSE: 0.015, MAE: 0.011

# %%
# predicting y_test values
print(X_test.shape)
predicted_values = model.predict(X_test)
print(predicted_values.shape)
# print(predicted_values)
# Out:
# (240, 60, 2)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# (240, 1)

# %%
plt.plot(y_test,c = 'r')
plt.plot(predicted_values,c = 'y')
plt.xlabel('Day')
plt.ylabel('Stock Price Volume')
plt.title('Stock Price Volume Prediction Graph using RNN (LSTM)')
plt.legend(['Actual','Predicted'],loc = 'lower right')
plt.figure(figsize=(10,6))

# %%
# evaluating using R squared
R_square = r2_score(y_test, predicted_values)

print(R_square)
# Out:
# 0.9965783062159289
